# %%
try:
    import sunpy
except ImportError:
    # %pip install "sunpy[all]"==7.1.2

try:
    import numpy
except ImportError:
    # %pip install numpy==2.2.6
    
try:
    import astropy
except ImportError:
    # %pip install astropy==7.2.0
    
try:
    import aiapy
except ImportError:
    # %pip install aiapy==0.12.0

# %%
import numpy
